# %% [markdown]
# <a href="https://colab.research.google.com/github/sukumar44/Lab-experiments/blob/main/8_Text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS
from gtts import gTTS
text_to_say="Welcome to the Text to Speech conversion session at Kalasalingam University"
language = 'en'
gtts_object = gTTS(text = text_to_say, lang = language, slow = False)
gtts_object.save("/content/gtts.wav")
from IPython.display import Audio
Audio("/content/gtts.wav")
# Out:
# ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
